# %% [markdown]
# <a href="https://colab.research.google.com/github/Dinarque/AI_Agents_Paris_Cite/blob/main/labs/AI_Agents_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI Agents (TP1) : From LLM to product
#
# # Open AI API vs ChaptGPT : the 7 differences
#
# The goal of this lab is to understand the difference between a single LLM and its integration into a broader product.
#
# You will experiment some basic requests with GPT on the web interface and the python library thant enables to call Open AI models, provided that you have an API key and some funds provisionned (which I do not demand from you, you can definitly answer only using the library and API documentation)
#
# https://chatgpt.com/
#
# https://github.com/openai/openai-python
#
# The objective of this lab are:
# * understanding the differences between a LLM and an AI application by comparing Chat GPT as it is in 2025 with what it was initially in 2022 at its launch
# * reflecting from a product perspective and trying to see all that is hidden from the user
# * Having a first glimpse of what an agentic application looks like

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# NB : image generated by ... chatgpt

# %% [markdown]
# ## 1) Conceptual differences
#
# What is chat GPT ? What is GPT ?
# Define what is a GUI, an API, a SDK and explain the differences between them

# %% [markdown]
# # 2) From the simplest generation
#
# Try to run the query "Who gives the best class about AI agents in Paris ?"  both via chat GPT UI and using the API https://platform.openai.com/docs/guides/text
#
#
# * What are the differences ?
# * Which parameters do you have access to with the API than you cant tune on the web interface ?
# Define these parameters and explain what they do. Can you access to some of them in the parameters ? Do you find it intuitive ?

# %% [markdown]
# ## 3) Continuing the conversation
#
# In question two GPT might advise you to do a Master's Degree at Polytechnique, but you are already in the best NLP degree of this country.
#
# So as a follow up, ask him "How about Louis Jourdain ?" (NB: I am not egocentric I'm just being silly)
#
# * In chat GPT'UI, its very easy to continue a conversation, you just type the message in the same conversation window
#
# * What should you do to do the same using the API ?
#
# * How should conversation be formated with Chat GPT ? What is a "role" ?

# %% [markdown]
# ## 4) Adding some personality
#
# Casual chatbots are boring. An educated chatbot would speak like Shakespeare.
#
# * I want the chatbot to speak in rhymes during the whole conversation without having to specify it at each conversational turn. What should I do ?
#
# * How is it possible to do it in the API ? (hint : leverage the structure of the conversation object)
#
# * How to do so in the web application ? is there a way to personalize the system prompt ?

# %% [markdown]
# ## 5) Call me by my name.
#
# Tell ChatGPT your name in the UI.
# Then open a whole new conversation and ask it what's your name.
#
# * Try the same with the API.
# What happens?
#
# * Explain by which mechanism GPT remembers your name

# %% [markdown]
# ## 6) Lets code
#
# Mr Wisniewski gave you a very complex lab about pandas and you are too lazy to do it by yourself.
#
# * Copy paste a question asking GPT to draw a heatmpap on a dataset you upload.
# What happens ?
#
# * Try to emulate these results using the API

# %% [markdown]
# ## 7) Deep research
#
# * Look in Open AI's documentation. What is deep research ?
#
# * Try to use it. Describe the different steps and what it does.
#
# * Can you emulate that with the API ?
# What will happen in the background ?
#
# * Which model is used during a Deep research ? Can we use it outside of the feature ?

# %% [markdown]
# ## 8) What are all these little icons ?
#
# We ll try to understand what happens when we click on the "+" in the bottom left corner of char GPT UI

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * try to select or deselect some combinations of features among those. What happens ?
#
# * unselect everything and ask
# "generate the image of a kangoroo"
# "research the timetable of Paris Cité NLP Degree"
# What happens ?
# How many Ai models were called ?
#
# * Can you emulate this behavious with the API ?

# %% [markdown]
# ## 9) The controversy around GPT 5
#
# GPT5 was not welcomed warmly. Among the reasons why one is particularly interesting for us
# What changed between before GPT5 's release and after from a user's perspective when using the Web application ?
# What are the benefits / limitations of this change ?

# %% [markdown]
# # 10) Circling back
#
# From the insight gained by answering all my silly questions, define what https://chatgpt.com/ 's backend is, from an engineering's point of view.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# PS : GPT thinks this class is the best in town !
